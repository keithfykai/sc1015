# %%
import numpy as np
import pandas as pd

# %%
house_prices = pd.read_csv('./train.csv')

# %%
type(house_prices)
# Out:
# pandas.core.frame.DataFrame

# %%
house_prices
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
print(house_prices.dtypes)
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
#                   ...
# MoSold             int64
# YrSold             int64
# SaleType          object
# SaleCondition     object
# SalePrice          int64
# Length: 81, dtype: object

# %%
house_prices.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
import seaborn as sb
import matplotlib.pyplot as plt
sb.set()

# %%
house_price = pd.DataFrame(house_prices)
house_price
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
print(house_prices.dtypes)
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
#                   ...
# MoSold             int64
# YrSold             int64
# SaleType          object
# SaleCondition     object
# SalePrice          int64
# Length: 81, dtype: object

# %%
onlyint64columns = house_price.select_dtypes(include=['int64'])
onlyint64columns
# Out:
#         Id  MSSubClass  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0        1          60     8450            7            5       2003
# 1        2          20     9600            6            8       1976
# 2        3          60    11250            7            5       2001
# 3        4          70     9550            7            5       1915
# 4        5          60    14260            8            5       2000
# ...    ...         ...      ...          ...          ...        ...
# 1455  1456          60     7917            6            5       1999
# 1456  1457          20    13175            6            6       1978
# 1457  1458          70     9042            7            9       1941
# 1458  1459          20     9717            5            6       1950
# 1459  1460          20     9937            5            6       1965
#
#       YearRemodAdd  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  ...  WoodDeckSF  \
# ...

# %%
onlyint64columns = house_prices.drop(columns=['MSSubClass','OverallCond','OverallQual'])
onlyint64columns.select_dtypes(include=['int64'])
# Out:
#         Id  LotArea  YearBuilt  YearRemodAdd  BsmtFinSF1  BsmtFinSF2  \
# 0        1     8450       2003          2003         706           0
# 1        2     9600       1976          1976         978           0
# 2        3    11250       2001          2002         486           0
# 3        4     9550       1915          1970         216           0
# 4        5    14260       2000          2000         655           0
# ...    ...      ...        ...           ...         ...         ...
# 1455  1456     7917       1999          2000           0           0
# 1456  1457    13175       1978          1988         790         163
# 1457  1458     9042       1941          2006         275           0
# 1458  1459     9717       1950          1996          49        1029
# 1459  1460     9937       1965          1965         830         290
#
#       BsmtUnfSF  TotalBsmtSF  1stFlrSF  2ndFlrSF  ...  WoodDeckSF  \
# 0           150          856       856       854  ...           0
# ...

# %% [markdown]
# Find the Summary Statistics (Mean, Median, Quartiles etc.) using.describe of SalePrice from the Numeric DataFrame.

# %%
onlyint64columns.describe()
# Out:
#                 Id  LotFrontage        LotArea    YearBuilt  YearRemodAdd  \
# count  1460.000000  1201.000000    1460.000000  1460.000000   1460.000000
# mean    730.500000    70.049958   10516.828082  1971.267808   1984.865753
# std     421.610009    24.284752    9981.264932    30.202904     20.645407
# min       1.000000    21.000000    1300.000000  1872.000000   1950.000000
# 25%     365.750000    59.000000    7553.500000  1954.000000   1967.000000
# 50%     730.500000    69.000000    9478.500000  1973.000000   1994.000000
# 75%    1095.250000    80.000000   11601.500000  2000.000000   2004.000000
# max    1460.000000   313.000000  215245.000000  2010.000000   2010.000000
#
#         MasVnrArea   BsmtFinSF1   BsmtFinSF2    BsmtUnfSF  TotalBsmtSF  ...  \
# count  1452.000000  1460.000000  1460.000000  1460.000000  1460.000000  ...
# mean    103.685262   443.639726    46.549315   567.240411  1057.429452  ...
# ...

# %%
SalePrice = pd.DataFrame(onlyint64columns['SalePrice'])
SalePrice.head()
# Out:
#    SalePrice
# 0     208500
# 1     181500
# 2     223500
# 3     140000
# 4     250000

# %%
SalePrice.describe()
# Out:
#            SalePrice
# count    1460.000000
# mean   180921.195890
# std     79442.502883
# min     34900.000000
# 25%    129975.000000
# 50%    163000.000000
# 75%    214000.000000
# max    755000.000000

# %% [markdown]
# 2b. Visualize the summary statistics and distribution of SalePrice using standard Box-Plot, Histogram, KDE
#
# using the methods:
#
# for boxplots:
#
# f = plt.figure(figsize=(24, 4))
#     sb.boxplot(data = onlyint64columns, orient = "h")
#
# For Histograms
#
# f = plt.figure(figsize=(16, 8))
# sb.histplot(data = onlyint64columns)
#
# for KDE (Kernel Density Estimate
#
# f = plt.figure(figsize=(16, 8))
# sb.kdeplot(data = hp)

# %%
f = plt.figure(figsize=(15, 5))
sb.boxplot(data = SalePrice, orient = "h")
# Out:
# <AxesSubplot:>

# %%
f = plt.figure(figsize=(16, 8))
sb.histplot(data = SalePrice)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
f = plt.figure(figsize=(16, 8))
sb.kdeplot(data = SalePrice)
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
LotArea = pd.DataFrame(onlyint64columns['LotArea'])
LotArea.describe()
# Out:
#              LotArea
# count    1460.000000
# mean    10516.828082
# std      9981.264932
# min      1300.000000
# 25%      7553.500000
# 50%      9478.500000
# 75%     11601.500000
# max    215245.000000

# %%
LotAreaBoxPlot = plt.figure(figsize=(15,5))
sb.boxplot(data=LotArea, orient='h')
# Out:
# <AxesSubplot:>

# %%
LotAreaHistogram = plt.figure(figsize=(15,5))
sb.histplot(data=LotArea)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
LotAreaKDE = plt.figure(figsize=(15,5))
sb.kdeplot(data=LotArea)
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
jointplotmoment = pd.concat([SalePrice,LotArea],axis=1)
jointplotmoment
# Out:
#       SalePrice  LotArea
# 0        208500     8450
# 1        181500     9600
# 2        223500    11250
# 3        140000     9550
# 4        250000    14260
# ...         ...      ...
# 1455     175000     7917
# 1456     210000    13175
# 1457     266500     9042
# 1458     142125     9717
# 1459     147500     9937
#
# [1460 rows x 2 columns]

# %%
sb.jointplot(data=jointplotmoment, x='LotArea', y='SalePrice', height=12)

# %%
jointplotmoment.corr()
# Out:
#            SalePrice   LotArea
# SalePrice   1.000000  0.263843
# LotArea     0.263843  1.000000

# %% [markdown]
# Heatmap to visualize better

# %%
sb.heatmap(jointplotmoment.corr(),vmin=-1,vmax=1,annot=True,fmt=".2f")
# Out:
# <AxesSubplot:>
